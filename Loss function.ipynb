# %%
# Loss Function ---> y_actual - y_predicted

# Numerical data scenario ---> MSE,MAE
# Categorical data  scenerio --->
# 1) When we have 2 sub categories in target column - Binarycross entropy
# 2) When we have more than 2 sub categories  in target column -  CategoricalCross  entropy/Sparsecategorical cross entropy

# %%
# Optimizers ----> Reduce  or minimize the distance from predicted point to actual point

# %%
# We know that equation of simple line is :
# y_act = mx +b   ....(1)
# y_pred =  mx + b

# here (x,y) ---> co-ordinates ,  m =  slope, b= intercept

# Now we will calculate Loss w.r.t. MSE
# L=1/n* (y_act -  y_pred)**2
# n= n(features)==> let suppose if we have 1 column ---> n(features)=1

# L=(y_act - y_pred)**2
# L=(y-(mx+b))**2
# L=(y-mx-b)**2 ........(2)

# Equ(2) differentiate calculate w.r.t. intercept(b)::::
# dl/db = 2(y-mx-b)[dy/db - dmx/db - db/db]
# dl/db = 2(y-mx-b)[0-0-1]
# dl/db = -2(y-mx-b)  ........(3)


# Equ(2) differentiate calculate w.r.t. slope(m)::::
# dl/dm = 2(y-mx-b)[dy/dm - dmx/dm - db/dm]
# dl/dm = 2(y-mx-b)[0-x-0]
# dl/dm = -2(y-mx-b) (x) ........(4)

# Now,
# In general lr = 0.001

# b_new = b_old - learning_rate * dL/db .....(5)

# m_new = m_old - learning_rate * dL/dm .....(6)

# So , our finally New Line Equation will be ::::

# y = m_new*X + b_new ...........(7)
