# %%
[1] # Random Forest ---- > Supervised Machine learning model
# (a). Numerical--- > RandomForestRegressor ---- >Backend--- > 100 D.T. --- > MSE --- > Final output
# (b). Categorical--- > RandomForestClassifier --- >Backend--- > 100 D.T. --- >
# 70 yes , 30 No --- > Final output based on majority (yes)
# Out:
# [1]

# %% [markdown]
# # Random Forest Classifier

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid_toy.csv")

# %%
df.head(1)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df["fever"]=si.fit_transform(df[["fever"]])

# %%
df.head(1)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["gender"]=lb.fit_transform(df["gender"])
df["cough"]=lb.fit_transform(df["cough"])
df["city"]=lb.fit_transform(df["city"])
df["has_covid"]=lb.fit_transform(df["has_covid"])

# %%
df.head(1)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0

# %%
x=df.drop(columns=["has_covid"])
y=df["has_covid"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf =  RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.45

# %% [markdown]
# # Random Forest Regressor

# %%
df=pd.read_csv(" insurance.csv")

# %%
df.head(1)
# Out:
#    age     sex   bmi  children smoker     region    charges
# 0   19  female  27.9         0    yes  southwest  16884.924

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["sex"]=lb.fit_transform(df["sex"])
df["smoker"]=lb.fit_transform(df["smoker"])
df["region"]=lb.fit_transform(df["region"])

# %%
x=df.drop(columns=["charges"])
y=df["charges"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8638373700328582

# %%
cvx6
