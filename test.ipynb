# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dsjob.csv")

# %%
df.head(2)
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
#
#    training_hours
# 0              21
# 1              98

# %%
# df.isnull().sum()

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df1["city"]=lb.fit_transform(df1["city"])
df1["gender"]=lb.fit_transform(df1["gender"])
df1["relevent_experience"]=lb.fit_transform(df1["relevent_experience"])
df1["enrolled_university"]=lb.fit_transform(df1["enrolled_university"])
df1["education_level"]=lb.fit_transform(df1["education_level"])
df1["major_discipline"]=lb.fit_transform(df1["major_discipline"])
df1["company_type"]=lb.fit_transform(df1["company_type"])
df1["experience"]=lb.fit_transform(df1["experience"])
df1["last_new_job"]=lb.fit_transform(df1["last_new_job"])
df1["company_size"]=lb.fit_transform(df1["company_size"])

# %%
df.head(2)
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
#
#    training_hours
# 0              21
# 1              98

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# company_size              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# %%
# si=SimpleImputer()

# %%
# si=SimpleImputer(strategy="most_frequent")

# %%
# df["last_new_job"]=si.fit_transform(df[["last_new_job"]]).ravel()

# %%
# df["company_size"]=df["company_size"].fillna(df["company_size"].mean())

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# company_size              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x=df1.drop(columns=["experience"])
y=df1["experience"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
np.round(x_train.describe(),2)
# Out:
#        enrollee_id     city  city_development_index   gender  \
# count      1703.00  1703.00                 1703.00  1703.00
# mean      16942.03    38.40                    0.83     1.43
# std        9591.51    30.02                    0.12     0.92
# min           3.00     0.00                    0.45     0.00
# 25%        8771.50     6.00                    0.70     1.00
# 50%       16972.00    41.00                    0.90     1.00
# 75%       25177.00    55.00                    0.92     1.00
# max       33353.00   107.00                    0.95     3.00
#
#        relevent_experience  enrolled_university  education_level  \
# count              1703.00              1703.00          1703.00
# mean                  0.29                 1.54             0.83
# std                   0.45                 0.82             1.18
# min                   0.00                 0.00             0.00
# 25%                   0.00                 1.00             0.00
# ...

# %%
df_ord=df.copy()
df_ord.head(2)
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
#
#    training_hours
# 0              21
# 1              98
