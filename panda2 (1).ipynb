# 19  https://www.flipkart.com/apple-iphone-16e-blac...
# 20  https://www.flipkart.com/samsung-galaxy-s25-ul...
# 21  https://www.flipkart.com/samsung-galaxy-s25-ul...
# 22  https://www.flipkart.com/apple-iphone-16e-whit...
# 23  https://www.flipkart.com/apple-iphone-15-black...
#
#                                                 PHONE  RATING  \
# 19                   Apple iPhone 16e (Black, 256 GB)     4.6
# 20  Samsung Galaxy S25 Ultra 5G (Titanium Gray, 51...     4.7
# 21  Samsung Galaxy S25 Ultra 5G (Titanium Black, 2...     4.7
# 22                   Apple iPhone 16e (White, 128 GB)     4.6
# 23                    Apple iPhone 15 (Black, 128 GB)     4.6
#
#        TOTAL_RATINGS        REVIEWS            RAM_STOREAGE  \
# 19     1,033 Ratings     57 Reviews              256 GB ROM
# 20     1,695 Ratings    203 Reviews  12 GB RAM | 512 GB ROM
# 21     1,695 Ratings    203 Reviews  12 GB RAM | 256 GB ROM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LINKS             24 non-null     object
#  1   PHONE             24 non-null     object
#  2   RATING            24 non-null     float64
#  3   TOTAL_RATINGS     24 non-null     object
#  4   REVIEWS           24 non-null     object
#  5   RAM_STOREAGE      24 non-null     object
#  6   J+igdf 3          24 non-null     object
#  7   BATTERY           24 non-null     object
#  8   PROCESSOR         24 non-null     object
#  9   WARRANTY          12 non-null     object
#  10  DICOUNT_PRICE     24 non-null     object
#  11  ORIGINAL_PRICE    23 non-null     object
#  12  DISCOUNT_PERCENT  23 non-null     object
#  13  DELIVERY          24 non-null     object
# dtypes: float64(1), object(13)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#           RATING
# count  24.000000
# mean    4.625000
# std     0.067566
# min     4.500000
# 25%     4.600000
# 50%     4.600000
# 75%     4.700000
# max     4.700000

# %%
df.shape
# Out:
# (24, 14)

# %%
df.columns
# Out:
# Index(['LINKS', 'PHONE', 'RATING', 'TOTAL_RATINGS', 'REVIEWS', 'RAM_STOREAGE',
#        'J+igdf 3', 'BATTERY', 'PROCESSOR', 'WARRANTY', 'DICOUNT_PRICE',
#        'ORIGINAL_PRICE', 'DISCOUNT_PERCENT', 'DELIVERY'],
#       dtype='object')

# %%
df.dtypes
# Out:
# LINKS                object
# PHONE                object
# RATING              float64
# TOTAL_RATINGS        object
# REVIEWS              object
# RAM_STOREAGE         object
# J+igdf 3             object
# BATTERY              object
# PROCESSOR            object
# WARRANTY             object
# DICOUNT_PRICE        object
# ORIGINAL_PRICE       object
# DISCOUNT_PERCENT     object
# DELIVERY             object
# dtype: object

# %%
df.nunique()
# Out:
# LINKS               24
# PHONE               24
# RATING               3
# TOTAL_RATINGS        7
# REVIEWS              7
# RAM_STOREAGE         5
# J+igdf 3             5
# BATTERY              5
# PROCESSOR            4
# WARRANTY             2
# DICOUNT_PRICE       10
# ORIGINAL_PRICE       9
# DISCOUNT_PERCENT     6
# DELIVERY             1
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index               132
# LINKS               192
# PHONE               192
# RATING              192
# TOTAL_RATINGS       192
# REVIEWS             192
# RAM_STOREAGE        192
# J+igdf 3            192
# BATTERY             192
# PROCESSOR           192
# WARRANTY            192
# DICOUNT_PRICE       192
# ORIGINAL_PRICE      192
# DISCOUNT_PERCENT    192
# DELIVERY            192
# dtype: int64

# %%
a = {
'student_name':['bablu','lalit','munna','babli'],
'roll_no':[1,4,12,18],
'marks':[73,70,72,26],
'admission_no':[1423,2753,9368,3028],
}

# %%
df = pd.DataFrame(a)
df
# Out:
#   student_name  roll_no  marks  admission_no
# 0        bablu        1     73          1423
# 1        lalit        4     70          2753
# 2        munna       12     72          9368
# 3        babli       18     26          3028

# %%
ad = pd.read_csv("D:\\google (2).csv")
ad
# Out:
#                                                 LINKS  \
# 0   https://www.worldtrips.com/resources/best-trav...
# 1   https://mize.tech/blog/the-top-13-online-trave...
# 2               https://www.incredibleindia.gov.in/en
# 3   https://www.semrush.com/website/top/global/tra...
# 4   https://go.photoshelter.com/brands/blog/best-t...
# 5   https://www.statista.com/statistics/1215457/mo...
# 6   https://www.hectindia.com/blog/top-50-best-tra...
# 7   https://www.webfx.com/industries/tourism-hospi...
# 8      https://mycodelesswebsite.com/tourism-website/
# 9   https://www.cyberoptik.net/blog/best-tourism-w...
# 10            https://www.thomascook.in/india-tourism
#
#                                           SEARCH_TAGS  \
# 0                                Best Travel Websites
# 1   The Top 13 Online Travel Agencies in India - m...
# 2   Discover Incredible India: Travel Guide & Tour...
# 3   Most Visited Travel and Tourism Websites in th...
# ...

# %%
ad.head()
# Out:
#                                                LINKS  \
# 0  https://www.worldtrips.com/resources/best-trav...
# 1  https://mize.tech/blog/the-top-13-online-trave...
# 2              https://www.incredibleindia.gov.in/en
# 3  https://www.semrush.com/website/top/global/tra...
# 4  https://go.photoshelter.com/brands/blog/best-t...
#
#                                          SEARCH_TAGS  \
# 0                               Best Travel Websites
# 1  The Top 13 Online Travel Agencies in India - m...
# 2  Discover Incredible India: Travel Guide & Tour...
# 3  Most Visited Travel and Tourism Websites in th...
# 4  6 Tourism Websites to Inspire Your Brand's Vis...
#
#                          NAMES  \
# 0  WorldTrips Travel Insurance
# 1                    mize.tech
# 2             Incredible India
# 3                      Semrush
# 4                 PhotoShelter
#
#                                      TRAVEL_BOOKINGS
# 0  You'll discover the  to browse for flights, ho...
# ...

# %%
ad.nunique()
# Out:
# LINKS              11
# SEARCH_TAGS        11
# NAMES              11
# TRAVEL_BOOKINGS    10
# dtype: int64

# %%
ad.shape
# Out:
# (11, 4)

# %%
ad.columns
# Out:
# Index(['LINKS', 'SEARCH_TAGS', 'NAMES', 'TRAVEL_BOOKINGS'], dtype='object')

# %%
ad.tail()
# Out:
#                                                 LINKS  \
# 6   https://www.hectindia.com/blog/top-50-best-tra...
# 7   https://www.webfx.com/industries/tourism-hospi...
# 8      https://mycodelesswebsite.com/tourism-website/
# 9   https://www.cyberoptik.net/blog/best-tourism-w...
# 10            https://www.thomascook.in/india-tourism
#
#                                           SEARCH_TAGS                NAMES  \
# 6   Top 50 Best Travel Websites from India for Fli...           HECT India
# 7   25 Tourism Website Designs That Make You Want ...                WebFX
# 8   Best Tourism Websites of 2025 | 24 Inspiring T...  My Codeless Website
# 9                            20 Best Tourism Websites           CyberOptik
# 10  Visit Best Tourist Places in India | Tourism i...          Thomas Cook
#
#                                       TRAVEL_BOOKINGS
# 6   · 2. MakeMyTrip · 3. Indian Railways · 4. Trip...
# 7   We've created this list of  to help you get in...
# ...
